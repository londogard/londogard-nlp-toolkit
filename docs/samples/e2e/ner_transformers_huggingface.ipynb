// %%
@file:DependsOn("com.londogard:nlp:1.2.0-BETA3")
// Out:
//             <div id="kotlin_out_0"/>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@d6467c1389bc031958acd5310fce39167b5cc581/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
// ...

// %% [markdown]
// # Named Entity Recognition
//
// Let's do some NER using Transformers via HuggingFace

// %%
import com.londogard.nlp.meachinelearning.predictors.transformers.TokenClassificationPipeline

val pipeline = TokenClassificationPipeline.create("optimum/bert-base-NER")
val result = pipeline.predict("My name is Hampus, I live in Sweden.")

result
// Out:
// Loading:     100% |████████████████████████████████████████|
// [O, O, O, B-PER, B-PER, O, O, O, O, B-LOC, O]
